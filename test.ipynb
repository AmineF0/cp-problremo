# %%
import pdfplumber
import pandas as pd
print(pdfplumber.__version__)
# Out:
# 0.6.0

# %%
pdf = pdfplumber.open("e.pdf")
p0 = pdf.pages[0]
table_settings = {
    "vertical_strategy": "lines",
    "horizontal_strategy": "text",
    "snap_y_tolerance": 5,
    "intersection_x_tolerance": 15,
}
table = p0.extract_table()
pd.DataFrame(table)
# Out:
#                       0     1   \
# 0                         None
# 1            di\nn\nu\nL    S1
# 2                   None    S2
# 3                   None    S3
# 4                   None    S4
# 5                   None    S5
# 6                   None    S6
# 7            di\nr\na\nM    S1
# 8                   None    S2
# 9                   None    S3
# 10                  None    S4
# 11                  None    S5
# 12                  None    S6
# 13  di\ne\nr\nc\nr\ne\nM    S1
# 14                  None    S2
# 15                  None    S3
# 16                  None    S4
# 17                  None    S5
# 18                  None    S6
# 19           di\nu\ne\nJ    S1
# 20                  None    S2
# 21                  None    S3
# 22                  None    S4
# 23                  None    S5
# 24                  None    S6
#
#                                                    2             3   \
# ...

# %%
import camelot
df = camelot.read_pdf("e.pdf")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12156/3031230939.py in <module>
#       1 import camelot
# ----> 2 df = camelot.read_pdf("e.pdf")
#       3 df
#
# AttributeError: module 'camelot' has no attribute 'read_pdf'
